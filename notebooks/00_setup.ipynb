# %%
api_key =  dbutils.secrets.get(
    scope="coingecko",
    key="api-key"
)

spark.sql("CREATE CATALOG IF NOT EXISTS coingecko")
spark.sql("CREATE SCHEMA IF NOT EXISTS coingecko.bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS coingecko.silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS coingecko.gold")
